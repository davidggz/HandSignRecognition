# %%
import pandas as pd
import numpy as np
import keras as keras
import matplotlib.pyplot as plt
import cv2
from PIL import Image

path_npy = "DatasetsIAO/Letras/"
letras_train_X = np.asarray(np.load(path_npy + "letras_train_X.npy"))

from keras.preprocessing.image import ImageDataGenerator

from keras.preprocessing import image
for example in [0, 1500, 3000, 4500, 6000]:
    imagenesNumeros = letras_train_X.reshape(-1, 28, 28, 1)
    imagen = letras_train_X[example]
    imagen = imagen.reshape(28, 28)

    im = Image.fromarray(imagen.astype('uint8'), 'L')
    im_resized64 = im.resize((64, 64), resample=Image.LANCZOS)
    plt.imshow(np.asarray(im_resized64), cmap='gray')
    plt.savefig("upscale64.png")
    plt.show()
    
    plt.imshow(np.asarray(imagen), cmap="gray")
    plt.savefig("upscaleOriginal.png")
    plt.show()
    
    im_resized56 = im.resize((56, 56), resample=Image.LANCZOS)
    plt.imshow(np.asarray(im_resized56), cmap='gray')
    plt.savefig("upscale56.png")
    plt.show()
